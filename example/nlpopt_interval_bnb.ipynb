# %% [markdown]
# # Using EAGO's basic optimizer with user-defined subroutines
#
# [Matthew Wilhelm](https://psor.uconn.edu/person/matthew-wilhelm/)
# Department of Chemical and Biomolecular Engineering, University of Connecticut

# %% [markdown]
# ### Overview
# In this section, we construct an optimizer that uses EAGO's basic nlp solution routine with user-defined lower and upper bounding problems. The **EAGO.Optimizer** structure supplies a number of parameters and stored structures that advanced users may find useful for constructing specialized solution routines. For a full review, of the EAGO.optimizer object the reader is directed to the **EAGO.Optimizer** docstring and documentation provided at [https://psorlab.github.io/EAGO.jl/stable/](https://psorlab.github.io/EAGO.jl/stable/).
#
# In this example, we'll forgo extensive integration into the EAGO.optimizer and simply replace the lower and upper-bounding problems to construct B&B routine that solves the following problem to global optimality using bounds obtained from interval arithmetic:
#
# $
# \begin{align}
# &\min_{\mathbf x \in X} \;\; \sin(x_1)x_2^2 - \cos(x_3) / x_4 \label{eq1} \\
# &X = [-10,10]\times[-1,1]\times[-10,10]\times[2,20].
# \end{align}
# $
#
# We begin importing EAGO, IntervalArithmetic[1], and JuMP[2].

# %%
using EAGO, IntervalArithmetic, JuMP

# %% [markdown]
# ### Defining a custom lower bounding problem
# A valid lower bound is obtained from the lower bound of the natural interval extension using the **ValidatedNumerics.jl** package. The LowerProblem used accepts the **EAGO.Optimizer** structure and a **EAGO.NodeBB** structure, computes the bound by method overloading interval arithmetic, and stores the results to the appropriate field of the **EAGO.Optimizer's** which is a mutable structure of type **EAGO.LowerInfo**. Note that the problem is unconstrained on the domain so we can assume it is always feasible.

# %%
function LowerProblem!(opt::EAGO.Optimizer, n::EAGO.NodeBB)
    x = Interval.(n.lower_variable_bounds,n.upper_variable_bounds)
    FInterval = sin(x[1])x[2]^2-cos(x[3])/x[4]
    opt.current_lower_info.value = FInterval.lo
    opt.current_lower_info.solution = mid.(x)
    opt.current_lower_info.feasibility = true
end
# Out:
# LowerProblem! (generic function with 1 method)

# %% [markdown]
# ### Defining a custom upper bounding problem
# Since the problem is unconstained, any feasible point represents a valid upper bound. If we arbitrarily take evaluate the function at the midpoint we obtain an upper bound. If an interval extension of the midpoint is used this upper bound is guaranteed to be valid inspite of any rounding error that may occur. The below function constructs an upper bound in this manner then stores the results to the appropriate field of the **EAGO.Optimizer's** which is a mutable structure of type **EAGO.UpperInfo**.

# %%
function UpperProblem!(opt::EAGO.Optimizer, n::EAGO.NodeBB)
    x_value = (n.upper_variable_bounds-n.lower_variable_bounds)/2.0
    x_interval = Interval.(x_value)
    FInterval = sin(x_interval[1])x_interval[2]^2-cos(x_interval[3])/x_interval[4]
    opt.current_upper_info.value = FInterval.hi
    opt.current_upper_info.solution = x_value
    opt.current_upper_info.feasibility = true
end
# Out:
# UpperProblem! (generic function with 1 method)

# %% [markdown]
# ### Build the JuMP Model and optimize
# We now add our optimizer to a JuMP model, provide variable bounds, user-defined functions, and optimize. Note that options can be provided to the EAGO optimizer using a series of keywords of a Dict{Symbol,Any} object. Both manners of providing options to EAGO are illustrated below.

# %%
# Creates a JuMP model with the the lower_problem, upper_problem, and absolute tolerance set by keyword arguments
m = JuMP.Model(with_optimizer(EAGO.Optimizer, lower_problem! = LowerProblem!, upper_problem! = UpperProblem!, 
                              absolute_tolerance = 0.001, obbt_depth = 0, dbbt_depth = 0, cp_depth = 0,
                              treat_as_nonlinear = Int[1; 2; 3; 4]))

# Create the same model m using an options dictionary
opt_dict = Dict{Symbol, Any}()
opt_dict[:lower_problem!] = LowerProblem!
opt_dict[:upper_problem!] = UpperProblem!
opt_dict[:absolute_tolerance] = 0.001
opt_dict[:obbt_depth] = 0
opt_dict[:dbbt_depth] = 0
opt_dict[:cp_depth] = 0
opt_dict[:treat_as_nonlinear] = [1; 2; 3; 4]

m = JuMP.Model(with_optimizer(EAGO.Optimizer; opt_dict...))

# Adds variables and bounds
x_L = [-10, -1, -10, 2]
x_U = [10, 1, 10, 20]
@variable(m, x_L[i] <= x[i=1:4] <= x_U[i])

# Solves the problem
JuMP.optimize!(m)
# Out:
# Node ID: 1, Lower Bound: -Inf, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [10.0, 1.0, 10.0, 20.0]
# started initial preprocessing
# finished initial preprocessing
# finished initial lower problem
# finished initial upper problem
# finished initial postprocessing
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [0.0, 0.0, 0.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [0.0, 0.0, 0.0, 11.0], Feasibility: true
# Upper Bound: -0.45079094099198574, Solution: [10.0, 1.0, 10.0, 9.0], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#      1,        2,      -1.5000000,     -Inf,     -0.4507909,           2,        Inf,       Inf,        true,       true
# Node ID: 2, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, 0.0, 0.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, 0.0, 0.0, 11.0], Feasibility: true
# Upper Bound: -0.8656941047657544, Solution: [5.0, 1.0, 10.0, 9.0], Feasibility: true
#      2,        3,      -1.5000000,     -1.5000000,     -0.8656941,           3,        0.6343059,       0.7327137,        true,       true
# Node ID: 4, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [0.0, 0.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, -0.5, 0.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, -0.5, 0.0, 11.0], Feasibility: true
# Upper Bound: -0.14650089876840086, Solution: [5.0, 0.5, 10.0, 9.0], Feasibility: true
#      3,        4,      -1.5000000,     -1.5000000,     -0.8656941,           4,        0.6343059,       0.7327137,        true,       true
# Node ID: 7, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, 0.0, 2.0], Upper Variable Bounds: [0.0, 0.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, -0.5, 5.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, -0.5, 5.0, 11.0], Feasibility: true
# Upper Bound: -0.2712490892728096, Solution: [5.0, 0.5, 5.0, 9.0], Feasibility: true
#      4,        5,      -1.5000000,     -1.5000000,     -0.8656941,           5,        0.6343059,       0.7327137,        true,       true
# Node ID: 9, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, 0.0, 11.0], Upper Variable Bounds: [0.0, 0.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.0909090909090915, Solution: [-5.0, -0.5, 5.0, 15.5], Feasibility: true
# Lower Bound (Last Iteration): -1.0909090909090915, Solution: [-5.0, -0.5, 5.0, 15.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#      5,        6,      -1.0909091,     -1.5000000,     -0.8656941,           6,        0.6343059,       0.7327137,        true,       true
# Node ID: 3, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [10.0, 1.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [5.0, 0.0, 0.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [5.0, 0.0, 0.0, 11.0], Feasibility: true
# Upper Bound: -0.8656941047657544, Solution: [5.0, 1.0, 10.0, 9.0], Feasibility: true
#      6,        7,      -1.5000000,     -1.5000000,     -0.8656941,           7,        0.6343059,       0.7327137,        true,       true
# Node ID: 13, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [10.0, 1.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [5.0, 0.5, 0.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [5.0, 0.5, 0.0, 11.0], Feasibility: true
# Upper Bound: -0.14650089876840086, Solution: [5.0, 0.5, 10.0, 9.0], Feasibility: true
#      7,        8,      -1.5000000,     -1.5000000,     -0.8656941,           8,        0.6343059,       0.7327137,        true,       true
# Node ID: 15, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.0, 0.0, 2.0], Upper Variable Bounds: [10.0, 1.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [5.0, 0.5, 5.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [5.0, 0.5, 5.0, 11.0], Feasibility: true
# Upper Bound: -0.2712490892728096, Solution: [5.0, 0.5, 5.0, 9.0], Feasibility: true
#      8,        9,      -1.5000000,     -1.5000000,     -0.8656941,           9,        0.6343059,       0.7327137,        true,       true
# Node ID: 14, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [10.0, 1.0, 0.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [5.0, 0.5, -5.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [5.0, 0.5, -5.0, 11.0], Feasibility: true
# Upper Bound: -0.2712490892728096, Solution: [5.0, 0.5, 5.0, 9.0], Feasibility: true
#      9,       10,      -1.5000000,     -1.5000000,     -0.8656941,          10,        0.6343059,       0.7327137,        true,       true
# Node ID: 18, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [10.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [5.0, 0.5, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [5.0, 0.5, -5.0, 6.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#     10,       11,      -1.5000000,     -1.5000000,     -0.8656941,          11,        0.6343059,       0.7327137,        true,       true
# Node ID: 16, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.0, 0.0, 2.0], Upper Variable Bounds: [10.0, 1.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [5.0, 0.5, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [5.0, 0.5, 5.0, 6.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#     11,       12,      -1.5000000,     -1.5000000,     -0.8656941,          12,        0.6343059,       0.7327137,        true,       true
# Node ID: 21, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [5.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [10.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.4589242746631392, Solution: [7.5, 0.5, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.4589242746631392, Solution: [7.5, 0.5, -5.0, 6.5], Feasibility: true
# Upper Bound: 0.08658199481193896, Solution: [2.5, 0.5, 5.0, 4.5], Feasibility: true
#     12,       13,      -1.4589243,     -1.5000000,     -0.8656941,          13,        0.6343059,       0.7327137,        true,       true
# Node ID: 19, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.0, -10.0, 11.0], Upper Variable Bounds: [10.0, 1.0, 0.0, 20.0]
# Lower Bound (First Iteration): -1.0909090909090915, Solution: [5.0, 0.5, -5.0, 15.5], Feasibility: true
# Lower Bound (Last Iteration): -1.0909090909090915, Solution: [5.0, 0.5, -5.0, 15.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#     13,       14,      -1.0909091,     -1.5000000,     -0.8656941,          14,        0.6343059,       0.7327137,        true,       true
# Node ID: 17, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.0, 0.0, 11.0], Upper Variable Bounds: [10.0, 1.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.0909090909090915, Solution: [5.0, 0.5, 5.0, 15.5], Feasibility: true
# Lower Bound (Last Iteration): -1.0909090909090915, Solution: [5.0, 0.5, 5.0, 15.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#     14,       15,      -1.0909091,     -1.5000000,     -0.8656941,          15,        0.6343059,       0.7327137,        true,       true
# Node ID: 8, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, 0.0, 2.0], Upper Variable Bounds: [0.0, 0.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, -0.5, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, -0.5, 5.0, 6.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#     15,       16,      -1.5000000,     -1.5000000,     -0.8656941,          16,        0.6343059,       0.7327137,        true,       true
# Node ID: 22, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.0, 0.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [2.5, 0.5, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [2.5, 0.5, 5.0, 6.5], Feasibility: true
# Upper Bound: 0.08658199481193896, Solution: [2.5, 0.5, 5.0, 4.5], Feasibility: true
#     16,       17,      -1.5000000,     -1.5000000,     -0.8656941,          17,        0.6343059,       0.7327137,        true,       true
# Node ID: 33, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.5, 0.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [2.5, 0.75, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [2.5, 0.75, 5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
#     17,       18,      -1.5000000,     -1.5000000,     -0.8656941,          18,        0.6343059,       0.7327137,        true,       true
# Node ID: 32, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.0, 0.0, 2.0], Upper Variable Bounds: [5.0, 0.5, 10.0, 11.0]
# Lower Bound (First Iteration): -0.7500000000000003, Solution: [2.5, 0.25, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -0.7500000000000003, Solution: [2.5, 0.25, 5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
#     18,       17,      -0.7500000,     -1.5000000,     -0.8656941,          17,        0.6343059,       0.7327137,        true,       true
# Node ID: 34, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.5, 0.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 5.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000009, Solution: [2.5, 0.75, 2.5, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000009, Solution: [2.5, 0.75, 2.5, 6.5], Feasibility: true
# Upper Bound: 0.21543642357248266, Solution: [2.5, 0.25, 2.5, 4.5], Feasibility: true
#     19,       18,      -1.5000000,     -1.5000000,     -0.8656941,          18,        0.6343059,       0.7327137,        true,       true
# Node ID: 39, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.5, 0.0, 6.5], Upper Variable Bounds: [5.0, 1.0, 5.0, 11.0]
# Lower Bound (First Iteration): -1.1538461538461546, Solution: [2.5, 0.75, 2.5, 8.75], Feasibility: true
# Lower Bound (Last Iteration): -1.1538461538461546, Solution: [2.5, 0.75, 2.5, 8.75], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#     20,       19,      -1.1538462,     -1.5000000,     -0.8656941,          19,        0.6343059,       0.7327137,        true,       true
# Node ID: 35, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.5, 5.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [2.5, 0.75, 7.5, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [2.5, 0.75, 7.5, 6.5], Feasibility: true
# Upper Bound: 0.21543642357248266, Solution: [2.5, 0.25, 2.5, 4.5], Feasibility: true
#     21,       20,      -1.5000000,     -1.5000000,     -0.8656941,          20,        0.6343059,       0.7327137,        true,       true
# Node ID: 43, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.5, 5.0, 6.5], Upper Variable Bounds: [5.0, 1.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.1538461538461546, Solution: [2.5, 0.75, 7.5, 8.75], Feasibility: true
# Lower Bound (Last Iteration): -1.1538461538461546, Solution: [2.5, 0.75, 7.5, 8.75], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     22,       21,      -1.1538462,     -1.5000000,     -0.8656941,          21,        0.6343059,       0.7327137,        true,       true
# Node ID: 42, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.5, 5.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 10.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [2.5, 0.75, 7.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [2.5, 0.75, 7.5, 4.25], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     23,       22,      -1.5000000,     -1.5000000,     -0.8656941,          22,        0.6343059,       0.7327137,        true,       true
# Node ID: 47, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [2.5, 0.5, 5.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 10.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [3.75, 0.75, 7.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [3.75, 0.75, 7.5, 4.25], Feasibility: true
# Upper Bound: 0.4153753678416949, Solution: [1.25, 0.25, 2.5, 2.25], Feasibility: true
#     24,       23,      -1.5000000,     -1.5000000,     -0.8656941,          23,        0.6343059,       0.7327137,        true,       true
# Node ID: 46, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.5, 5.0, 2.0], Upper Variable Bounds: [2.5, 1.0, 10.0, 6.5]
# Lower Bound (First Iteration): -0.5000000000000002, Solution: [1.25, 0.75, 7.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -0.5000000000000002, Solution: [1.25, 0.75, 7.5, 4.25], Feasibility: true
# Upper Bound: 0.4153753678416949, Solution: [1.25, 0.25, 2.5, 2.25], Feasibility: true
#     25,       22,      -0.5000000,     -1.5000000,     -0.8656941,          22,        0.6343059,       0.7327137,        true,       true
# Node ID: 49, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [2.5, 0.75, 5.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 10.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [3.75, 0.875, 7.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [3.75, 0.875, 7.5, 4.25], Feasibility: true
# Upper Bound: 0.3708917138094017, Solution: [1.25, 0.125, 2.5, 2.25], Feasibility: true
#     26,       23,      -1.5000000,     -1.5000000,     -0.8656941,          23,        0.6343059,       0.7327137,        true,       true
# Node ID: 52, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [2.5, 0.75, 5.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 7.5, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [3.75, 0.875, 6.25, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [3.75, 0.875, 6.25, 4.25], Feasibility: true
# Upper Bound: -0.12531538749824384, Solution: [1.25, 0.125, 1.25, 2.25], Feasibility: true
#     27,       24,      -1.5000000,     -1.5000000,     -0.8656941,          24,        0.6343059,       0.7327137,        true,       true
# Node ID: 54, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [2.5, 0.75, 5.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 7.5, 4.25]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [3.75, 0.875, 6.25, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [3.75, 0.875, 6.25, 3.125], Feasibility: true
# Upper Bound: -0.26545865967391874, Solution: [1.25, 0.125, 1.25, 1.125], Feasibility: true
#     28,       25,      -1.5000000,     -1.5000000,     -0.8656941,          25,        0.6343059,       0.7327137,        true,       true
# Node ID: 55, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [2.5, 0.75, 5.0, 4.25], Upper Variable Bounds: [5.0, 1.0, 7.5, 6.5]
# Lower Bound (First Iteration): -1.2352941176470595, Solution: [3.75, 0.875, 6.25, 5.375], Feasibility: true
# Lower Bound (Last Iteration): -1.2352941176470595, Solution: [3.75, 0.875, 6.25, 5.375], Feasibility: true
# Upper Bound: -0.26545865967391874, Solution: [1.25, 0.125, 1.25, 1.125], Feasibility: true
#     29,       26,      -1.2352941,     -1.5000000,     -0.8656941,          26,        0.6343059,       0.7327137,        true,       true
# Node ID: 6, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [0.0, 0.0, 0.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, -0.5, -5.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, -0.5, -5.0, 11.0], Feasibility: true
# Upper Bound: -0.2712490892728096, Solution: [5.0, 0.5, 5.0, 9.0], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#     30,       27,      -1.5000000,     -1.5000000,     -0.8656941,          27,        0.6343059,       0.7327137,        true,       true
# Node ID: 60, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [0.0, 0.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, -0.5, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, -0.5, -5.0, 6.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#     31,       28,      -1.5000000,     -1.5000000,     -0.8656941,          28,        0.6343059,       0.7327137,        true,       true
# Node ID: 62, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [-5.0, 0.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, -0.5, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, -0.5, -5.0, 6.5], Feasibility: true
# Upper Bound: 0.08658199481193896, Solution: [2.5, 0.5, 5.0, 4.5], Feasibility: true
#     32,       29,      -1.5000000,     -1.5000000,     -0.8656941,          29,        0.6343059,       0.7327137,        true,       true
# Node ID: 64, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [-5.0, -0.5, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, -0.75, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, -0.75, -5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
#     33,       30,      -1.5000000,     -1.5000000,     -0.8656941,          30,        0.6343059,       0.7327137,        true,       true
# Node ID: 66, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [-5.0, -0.5, -5.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, -0.75, -7.5, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, -0.75, -7.5, 6.5], Feasibility: true
# Upper Bound: 0.21543642357248266, Solution: [2.5, 0.25, 2.5, 4.5], Feasibility: true
#     34,       31,      -1.5000000,     -1.5000000,     -0.8656941,          31,        0.6343059,       0.7327137,        true,       true
# Node ID: 68, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [-5.0, -0.5, -5.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, -0.75, -7.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, -0.75, -7.5, 4.25], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     35,       32,      -1.5000000,     -1.5000000,     -0.8656941,          32,        0.6343059,       0.7327137,        true,       true
# Node ID: 69, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 6.5], Upper Variable Bounds: [-5.0, -0.5, -5.0, 11.0]
# Lower Bound (First Iteration): -1.1538461538461546, Solution: [-7.5, -0.75, -7.5, 8.75], Feasibility: true
# Lower Bound (Last Iteration): -1.1538461538461546, Solution: [-7.5, -0.75, -7.5, 8.75], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     36,       33,      -1.1538462,     -1.5000000,     -0.8656941,          33,        0.6343059,       0.7327137,        true,       true
# Node ID: 65, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -0.5, -10.0, 2.0], Upper Variable Bounds: [-5.0, 0.0, 0.0, 11.0]
# Lower Bound (First Iteration): -0.7500000000000003, Solution: [-7.5, -0.25, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -0.7500000000000003, Solution: [-7.5, -0.25, -5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
#     37,       32,      -0.7500000,     -1.5000000,     -0.8656941,          32,        0.6343059,       0.7327137,        true,       true
# Node ID: 53, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [2.5, 0.75, 7.5, 2.0], Upper Variable Bounds: [5.0, 1.0, 10.0, 6.5]
# Lower Bound (First Iteration): -1.1733176589175136, Solution: [3.75, 0.875, 8.75, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.1733176589175136, Solution: [3.75, 0.875, 8.75, 4.25], Feasibility: true
# Upper Bound: -0.12531538749824384, Solution: [1.25, 0.125, 1.25, 2.25], Feasibility: true
#     38,       33,      -1.1733177,     -1.5000000,     -0.8656941,          33,        0.6343059,       0.7327137,        true,       true
# Node ID: 61, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 11.0], Upper Variable Bounds: [0.0, 0.0, 0.0, 20.0]
# Lower Bound (First Iteration): -1.0909090909090915, Solution: [-5.0, -0.5, -5.0, 15.5], Feasibility: true
# Lower Bound (Last Iteration): -1.0909090909090915, Solution: [-5.0, -0.5, -5.0, 15.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#     39,       34,      -1.0909091,     -1.5000000,     -0.8656941,          34,        0.6343059,       0.7327137,        true,       true
# Node ID: 5, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, 0.5, 0.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, 0.5, 0.0, 11.0], Feasibility: true
# Upper Bound: -0.14650089876840086, Solution: [5.0, 0.5, 10.0, 9.0], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#     40,       35,      -1.5000000,     -1.5000000,     -0.8656941,          35,        0.6343059,       0.7327137,        true,       true
# Node ID: 80, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, 0.5, -5.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, 0.5, -5.0, 11.0], Feasibility: true
# Upper Bound: -0.2712490892728096, Solution: [5.0, 0.5, 5.0, 9.0], Feasibility: true
#     41,       36,      -1.5000000,     -1.5000000,     -0.8656941,          36,        0.6343059,       0.7327137,        true,       true
# Node ID: 81, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.0, 0.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, 0.5, 5.0, 11.0], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, 0.5, 5.0, 11.0], Feasibility: true
# Upper Bound: -0.2712490892728096, Solution: [5.0, 0.5, 5.0, 9.0], Feasibility: true
#     42,       37,      -1.5000000,     -1.5000000,     -0.8656941,          37,        0.6343059,       0.7327137,        true,       true
# Node ID: 82, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, 0.5, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, 0.5, -5.0, 6.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#     43,       38,      -1.5000000,     -1.5000000,     -0.8656941,          38,        0.6343059,       0.7327137,        true,       true
# Node ID: 86, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, 0.5, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, 0.5, -5.0, 6.5], Feasibility: true
# Upper Bound: 0.08658199481193896, Solution: [2.5, 0.5, 5.0, 4.5], Feasibility: true
#     44,       39,      -1.5000000,     -1.5000000,     -0.8656941,          39,        0.6343059,       0.7327137,        true,       true
# Node ID: 89, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, -10.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, -5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
#     45,       40,      -1.5000000,     -1.5000000,     -0.8656941,          40,        0.6343059,       0.7327137,        true,       true
# Node ID: 85, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.0, 0.0, 11.0], Upper Variable Bounds: [0.0, 1.0, 10.0, 20.0]
# Lower Bound (First Iteration): -1.0909090909090915, Solution: [-5.0, 0.5, 5.0, 15.5], Feasibility: true
# Lower Bound (Last Iteration): -1.0909090909090915, Solution: [-5.0, 0.5, 5.0, 15.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#     46,       41,      -1.0909091,     -1.5000000,     -0.8656941,          41,        0.6343059,       0.7327137,        true,       true
# Node ID: 57, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [3.75, 0.75, 5.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 7.5, 4.25]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [4.375, 0.875, 6.25, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [4.375, 0.875, 6.25, 3.125], Feasibility: true
# Upper Bound: -0.27114439946165503, Solution: [0.625, 0.125, 1.25, 1.125], Feasibility: true
#     47,       42,      -1.5000000,     -1.5000000,     -0.8656941,          42,        0.6343059,       0.7327137,        true,       true
# Node ID: 95, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [3.75, 0.875, 5.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 7.5, 4.25]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [4.375, 0.9375, 6.25, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [4.375, 0.9375, 6.25, 3.125], Feasibility: true
# Upper Bound: -0.2780010081289261, Solution: [0.625, 0.0625, 1.25, 1.125], Feasibility: true
#     48,       43,      -1.5000000,     -1.5000000,     -0.8656941,          43,        0.6343059,       0.7327137,        true,       true
# Node ID: 20, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [2.5, 0.5, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [2.5, 0.5, -5.0, 6.5], Feasibility: true
# Upper Bound: 0.08658199481193896, Solution: [2.5, 0.5, 5.0, 4.5], Feasibility: true
#     49,       44,      -1.5000000,     -1.5000000,     -0.8656941,          44,        0.6343059,       0.7327137,        true,       true
# Node ID: 90, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, -10.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, -5.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, -7.5, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, -7.5, 6.5], Feasibility: true
# Upper Bound: 0.21543642357248266, Solution: [2.5, 0.25, 2.5, 4.5], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#     50,       45,      -1.5000000,     -1.5000000,     -0.8656941,          45,        0.6343059,       0.7327137,        true,       true
# Node ID: 31, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-5.0, -1.0, 0.0, 2.0], Upper Variable Bounds: [0.0, 0.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-2.5, -0.5, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-2.5, -0.5, 5.0, 6.5], Feasibility: true
# Upper Bound: 0.08658199481193896, Solution: [2.5, 0.5, 5.0, 4.5], Feasibility: true
#     51,       46,      -1.5000000,     -1.5000000,     -0.8656941,          46,        0.6343059,       0.7327137,        true,       true
# Node ID: 70, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [-7.5, -0.5, -5.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-8.75, -0.75, -7.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-8.75, -0.75, -7.5, 4.25], Feasibility: true
# Upper Bound: 0.4153753678416949, Solution: [1.25, 0.25, 2.5, 2.25], Feasibility: true
#     52,       47,      -1.5000000,     -1.5000000,     -0.8656941,          47,        0.6343059,       0.7327137,        true,       true
# Node ID: 96, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [3.75, 0.875, 5.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 6.25, 4.25]
# Lower Bound (First Iteration): -1.4997247091122505, Solution: [4.375, 0.9375, 5.625, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.4997247091122505, Solution: [4.375, 0.9375, 5.625, 3.125], Feasibility: true
# Upper Bound: -0.7185705700044364, Solution: [0.625, 0.0625, 0.625, 1.125], Feasibility: true
#     53,       48,      -1.4997247,     -1.5000000,     -0.8656941,          48,        0.6343059,       0.7327137,        true,       true
# Node ID: 83, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.0, -10.0, 11.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 20.0]
# Lower Bound (First Iteration): -1.0909090909090915, Solution: [-5.0, 0.5, -5.0, 15.5], Feasibility: true
# Lower Bound (Last Iteration): -1.0909090909090915, Solution: [-5.0, 0.5, -5.0, 15.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#     54,       49,      -1.0909091,     -1.5000000,     -0.8656941,          49,        0.6343059,       0.7327137,        true,       true
# Node ID: 84, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.0, 0.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-5.0, 0.5, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-5.0, 0.5, 5.0, 6.5], Feasibility: true
# Upper Bound: -0.30276710987983474, Solution: [5.0, 0.5, 5.0, 4.5], Feasibility: true
#     55,       50,      -1.5000000,     -1.5000000,     -0.8656941,          50,        0.6343059,       0.7327137,        true,       true
# Node ID: 111, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-5.0, 0.0, 0.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-2.5, 0.5, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-2.5, 0.5, 5.0, 6.5], Feasibility: true
# Upper Bound: 0.08658199481193896, Solution: [2.5, 0.5, 5.0, 4.5], Feasibility: true
#     56,       51,      -1.5000000,     -1.5000000,     -0.8656941,          51,        0.6343059,       0.7327137,        true,       true
# Node ID: 112, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-5.0, 0.0, 0.0, 2.0], Upper Variable Bounds: [0.0, 0.5, 10.0, 11.0]
# Lower Bound (First Iteration): -0.7500000000000003, Solution: [-2.5, 0.25, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -0.7500000000000003, Solution: [-2.5, 0.25, 5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
#     57,       50,      -0.7500000,     -1.5000000,     -0.8656941,          50,        0.6343059,       0.7327137,        true,       true
# Node ID: 110, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.0, 0.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, 0.5, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, 0.5, 5.0, 6.5], Feasibility: true
# Upper Bound: 0.08658199481193896, Solution: [2.5, 0.5, 5.0, 4.5], Feasibility: true
#     58,       51,      -1.5000000,     -1.5000000,     -0.8656941,          51,        0.6343059,       0.7327137,        true,       true
# Node ID: 67, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -5.0, 2.0], Upper Variable Bounds: [-5.0, -0.5, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, -0.75, -2.5, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, -0.75, -2.5, 6.5], Feasibility: true
# Upper Bound: 0.21543642357248266, Solution: [2.5, 0.25, 2.5, 4.5], Feasibility: true
#     59,       52,      -1.5000000,     -1.5000000,     -0.8656941,          52,        0.6343059,       0.7327137,        true,       true
# Node ID: 99, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.5, -10.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [2.5, 0.75, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [2.5, 0.75, -5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#     60,       53,      -1.5000000,     -1.5000000,     -0.8656941,          53,        0.6343059,       0.7327137,        true,       true
# Node ID: 121, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [0.0, 0.5, -5.0, 2.0], Upper Variable Bounds: [5.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [2.5, 0.75, -2.5, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [2.5, 0.75, -2.5, 6.5], Feasibility: true
# Upper Bound: 0.21543642357248266, Solution: [2.5, 0.25, 2.5, 4.5], Feasibility: true
#     61,       54,      -1.5000000,     -1.5000000,     -0.8656941,          54,        0.6343059,       0.7327137,        true,       true
# Node ID: 117, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, 0.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, 5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
#     62,       55,      -1.5000000,     -1.5000000,     -0.8656941,          55,        0.6343059,       0.7327137,        true,       true
# Node ID: 124, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, 0.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 5.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000009, Solution: [-7.5, 0.75, 2.5, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000009, Solution: [-7.5, 0.75, 2.5, 6.5], Feasibility: true
# Upper Bound: 0.21543642357248266, Solution: [2.5, 0.25, 2.5, 4.5], Feasibility: true
#     63,       56,      -1.5000000,     -1.5000000,     -0.8656941,          56,        0.6343059,       0.7327137,        true,       true
# Node ID: 125, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, 5.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, 7.5, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, 7.5, 6.5], Feasibility: true
# Upper Bound: 0.21543642357248266, Solution: [2.5, 0.25, 2.5, 4.5], Feasibility: true
#     64,       57,      -1.5000000,     -1.5000000,     -0.8656941,          57,        0.6343059,       0.7327137,        true,       true
# Node ID: 127, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, 0.0, 6.5], Upper Variable Bounds: [-5.0, 1.0, 5.0, 11.0]
# Lower Bound (First Iteration): -1.1538461538461546, Solution: [-7.5, 0.75, 2.5, 8.75], Feasibility: true
# Lower Bound (Last Iteration): -1.1538461538461546, Solution: [-7.5, 0.75, 2.5, 8.75], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     65,       58,      -1.1538462,     -1.5000000,     -0.8656941,          58,        0.6343059,       0.7327137,        true,       true
# Node ID: 126, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, 0.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 5.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000009, Solution: [-7.5, 0.75, 2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000009, Solution: [-7.5, 0.75, 2.5, 4.25], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     66,       59,      -1.5000000,     -1.5000000,     -0.8656941,          59,        0.6343059,       0.7327137,        true,       true
# Node ID: 133, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-7.5, 0.5, 0.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 5.0, 6.5]
# Lower Bound (First Iteration): -1.4379999767747398, Solution: [-6.25, 0.75, 2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.4379999767747398, Solution: [-6.25, 0.75, 2.5, 4.25], Feasibility: true
# Upper Bound: 0.4153753678416949, Solution: [1.25, 0.25, 2.5, 2.25], Feasibility: true
#     67,       60,      -1.4380000,     -1.5000000,     -0.8656941,          60,        0.6343059,       0.7327137,        true,       true
# Node ID: 94, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [3.75, 0.75, 5.0, 2.0], Upper Variable Bounds: [5.0, 0.875, 7.5, 4.25]
# Lower Bound (First Iteration): -1.2656250000000007, Solution: [4.375, 0.8125, 6.25, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.2656250000000007, Solution: [4.375, 0.8125, 6.25, 3.125], Feasibility: true
# Upper Bound: -0.2780010081289261, Solution: [0.625, 0.0625, 1.25, 1.125], Feasibility: true
#     68,       61,      -1.2656250,     -1.5000000,     -0.8656941,          61,        0.6343059,       0.7327137,        true,       true
# Node ID: 105, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -0.75, -10.0, 2.0], Upper Variable Bounds: [-7.5, -0.5, -5.0, 6.5]
# Lower Bound (First Iteration): -1.0625000000000007, Solution: [-8.75, -0.625, -7.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.0625000000000007, Solution: [-8.75, -0.625, -7.5, 4.25], Feasibility: true
# Upper Bound: 0.3708917138094017, Solution: [1.25, 0.125, 2.5, 2.25], Feasibility: true
#     69,       62,      -1.0625000,     -1.5000000,     -0.8656941,          62,        0.6343059,       0.7327137,        true,       true
# Node ID: 30, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, 0.0, 2.0], Upper Variable Bounds: [-5.0, 0.0, 10.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, -0.5, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, -0.5, 5.0, 6.5], Feasibility: true
# Upper Bound: 0.08658199481193896, Solution: [2.5, 0.5, 5.0, 4.5], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#     70,       63,      -1.5000000,     -1.5000000,     -0.8656941,          63,        0.6343059,       0.7327137,        true,       true
# Node ID: 141, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -0.5, 0.0, 2.0], Upper Variable Bounds: [-5.0, 0.0, 10.0, 11.0]
# Lower Bound (First Iteration): -0.7500000000000003, Solution: [-7.5, -0.25, 5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -0.7500000000000003, Solution: [-7.5, -0.25, 5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
#     71,       62,      -0.7500000,     -1.5000000,     -0.8656941,          62,        0.6343059,       0.7327137,        true,       true
# Node ID: 101, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, -10.0, 6.5], Upper Variable Bounds: [-5.0, 1.0, -5.0, 11.0]
# Lower Bound (First Iteration): -1.1538461538461546, Solution: [-7.5, 0.75, -7.5, 8.75], Feasibility: true
# Lower Bound (Last Iteration): -1.1538461538461546, Solution: [-7.5, 0.75, -7.5, 8.75], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     72,       63,      -1.1538462,     -1.5000000,     -0.8656941,          63,        0.6343059,       0.7327137,        true,       true
# Node ID: 91, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, -5.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, -2.5, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, -2.5, 6.5], Feasibility: true
# Upper Bound: 0.21543642357248266, Solution: [2.5, 0.25, 2.5, 4.5], Feasibility: true
#     73,       64,      -1.5000000,     -1.5000000,     -0.8656941,          64,        0.6343059,       0.7327137,        true,       true
# Node ID: 146, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, -5.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 0.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, -2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, -2.5, 4.25], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     74,       65,      -1.5000000,     -1.5000000,     -0.8656941,          65,        0.6343059,       0.7327137,        true,       true
# Node ID: 148, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, -5.0, 2.0], Upper Variable Bounds: [-7.5, 1.0, 0.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-8.75, 0.75, -2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-8.75, 0.75, -2.5, 4.25], Feasibility: true
# Upper Bound: 0.4153753678416949, Solution: [1.25, 0.25, 2.5, 2.25], Feasibility: true
#     75,       66,      -1.5000000,     -1.5000000,     -0.8656941,          66,        0.6343059,       0.7327137,        true,       true
# Node ID: 151, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.75, -5.0, 2.0], Upper Variable Bounds: [-7.5, 1.0, 0.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-8.75, 0.875, -2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-8.75, 0.875, -2.5, 4.25], Feasibility: true
# Upper Bound: 0.3708917138094017, Solution: [1.25, 0.125, 2.5, 2.25], Feasibility: true
#     76,       67,      -1.5000000,     -1.5000000,     -0.8656941,          67,        0.6343059,       0.7327137,        true,       true
# Node ID: 150, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, -5.0, 2.0], Upper Variable Bounds: [-7.5, 0.75, 0.0, 6.5]
# Lower Bound (First Iteration): -1.0625000000000007, Solution: [-8.75, 0.625, -2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.0625000000000007, Solution: [-8.75, 0.625, -2.5, 4.25], Feasibility: true
# Upper Bound: 0.3708917138094017, Solution: [1.25, 0.125, 2.5, 2.25], Feasibility: true
#     77,       68,      -1.0625000,     -1.5000000,     -0.8656941,          68,        0.6343059,       0.7327137,        true,       true
# Node ID: 128, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, 5.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 10.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, 7.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-7.5, 0.75, 7.5, 4.25], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     78,       69,      -1.5000000,     -1.5000000,     -0.8656941,          69,        0.6343059,       0.7327137,        true,       true
# Node ID: 132, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, 0.0, 2.0], Upper Variable Bounds: [-7.5, 1.0, 5.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000009, Solution: [-8.75, 0.75, 2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000009, Solution: [-8.75, 0.75, 2.5, 4.25], Feasibility: true
# Upper Bound: 0.4153753678416949, Solution: [1.25, 0.25, 2.5, 2.25], Feasibility: true
#     79,       70,      -1.5000000,     -1.5000000,     -0.8656941,          70,        0.6343059,       0.7327137,        true,       true
# Node ID: 158, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, 0.0, 2.0], Upper Variable Bounds: [-7.5, 0.75, 5.0, 6.5]
# Lower Bound (First Iteration): -1.0625000000000007, Solution: [-8.75, 0.625, 2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.0625000000000007, Solution: [-8.75, 0.625, 2.5, 4.25], Feasibility: true
# Upper Bound: 0.3708917138094017, Solution: [1.25, 0.125, 2.5, 2.25], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#     80,       71,      -1.0625000,     -1.5000000,     -0.8656941,          71,        0.6343059,       0.7327137,        true,       true
# Node ID: 159, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.75, 0.0, 2.0], Upper Variable Bounds: [-7.5, 1.0, 5.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000009, Solution: [-8.75, 0.875, 2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000009, Solution: [-8.75, 0.875, 2.5, 4.25], Feasibility: true
# Upper Bound: 0.3708917138094017, Solution: [1.25, 0.125, 2.5, 2.25], Feasibility: true
#     81,       72,      -1.5000000,     -1.5000000,     -0.8656941,          72,        0.6343059,       0.7327137,        true,       true
# Node ID: 147, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, 0.5, -5.0, 6.5], Upper Variable Bounds: [-5.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.1538461538461546, Solution: [-7.5, 0.75, -2.5, 8.75], Feasibility: true
# Lower Bound (Last Iteration): -1.1538461538461546, Solution: [-7.5, 0.75, -2.5, 8.75], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     82,       73,      -1.1538462,     -1.5000000,     -0.8656941,          73,        0.6343059,       0.7327137,        true,       true
# Node ID: 157, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-7.5, 0.5, 5.0, 2.0], Upper Variable Bounds: [-5.0, 1.0, 10.0, 6.5]
# Lower Bound (First Iteration): -1.4379999767747396, Solution: [-6.25, 0.75, 7.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.4379999767747396, Solution: [-6.25, 0.75, 7.5, 4.25], Feasibility: true
# Upper Bound: 0.4153753678416949, Solution: [1.25, 0.25, 2.5, 2.25], Feasibility: true
#     83,       74,      -1.4380000,     -1.5000000,     -0.8656941,          74,        0.6343059,       0.7327137,        true,       true
# Node ID: 104, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [-7.5, -0.75, -5.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-8.75, -0.875, -7.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-8.75, -0.875, -7.5, 4.25], Feasibility: true
# Upper Bound: 0.3708917138094017, Solution: [1.25, 0.125, 2.5, 2.25], Feasibility: true
#     84,       75,      -1.5000000,     -1.5000000,     -0.8656941,          75,        0.6343059,       0.7327137,        true,       true
# Node ID: 168, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-10.0, -1.0, -10.0, 2.0], Upper Variable Bounds: [-7.5, -0.75, -7.5, 6.5]
# Lower Bound (First Iteration): -1.1733176589175136, Solution: [-8.75, -0.875, -8.75, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.1733176589175136, Solution: [-8.75, -0.875, -8.75, 4.25], Feasibility: true
# Upper Bound: -0.12531538749824384, Solution: [1.25, 0.125, 1.25, 2.25], Feasibility: true
#     85,       76,      -1.1733177,     -1.5000000,     -0.8656941,          76,        0.6343059,       0.7327137,        true,       true
# Node ID: 87, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-5.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-2.5, 0.5, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-2.5, 0.5, -5.0, 6.5], Feasibility: true
# Upper Bound: 0.08658199481193896, Solution: [2.5, 0.5, 5.0, 4.5], Feasibility: true
#     86,       77,      -1.5000000,     -1.5000000,     -0.8656941,          77,        0.6343059,       0.7327137,        true,       true
# Node ID: 173, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-5.0, 0.5, -10.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-2.5, 0.75, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-2.5, 0.75, -5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
#     87,       78,      -1.5000000,     -1.5000000,     -0.8656941,          78,        0.6343059,       0.7327137,        true,       true
# Node ID: 175, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-5.0, 0.5, -5.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 11.0]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-2.5, 0.75, -2.5, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-2.5, 0.75, -2.5, 6.5], Feasibility: true
# Upper Bound: 0.21543642357248266, Solution: [2.5, 0.25, 2.5, 4.5], Feasibility: true
#     88,       79,      -1.5000000,     -1.5000000,     -0.8656941,          79,        0.6343059,       0.7327137,        true,       true
# Node ID: 176, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-5.0, 0.5, -5.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-2.5, 0.75, -2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-2.5, 0.75, -2.5, 4.25], Feasibility: true
# Upper Bound: 0.393468338138468, Solution: [2.5, 0.25, 2.5, 2.25], Feasibility: true
#     89,       80,      -1.5000000,     -1.5000000,     -0.8656941,          80,        0.6343059,       0.7327137,        true,       true
# Node ID: 172, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-5.0, 0.0, -10.0, 2.0], Upper Variable Bounds: [0.0, 0.5, 0.0, 11.0]
# Lower Bound (First Iteration): -0.7500000000000003, Solution: [-2.5, 0.25, -5.0, 6.5], Feasibility: true
# Lower Bound (Last Iteration): -0.7500000000000003, Solution: [-2.5, 0.25, -5.0, 6.5], Feasibility: true
# Upper Bound: -0.02563153220755295, Solution: [2.5, 0.25, 5.0, 4.5], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#     90,       79,      -0.7500000,     -1.5000000,     -0.8656941,          79,        0.6343059,       0.7327137,        true,       true
# Node ID: 178, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-5.0, 0.5, -5.0, 2.0], Upper Variable Bounds: [-2.5, 1.0, 0.0, 6.5]
# Lower Bound (First Iteration): -1.098472144103957, Solution: [-3.75, 0.75, -2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.098472144103957, Solution: [-3.75, 0.75, -2.5, 4.25], Feasibility: true
# Upper Bound: 0.4153753678416949, Solution: [1.25, 0.25, 2.5, 2.25], Feasibility: true
#     91,       80,      -1.0984721,     -1.5000000,     -0.8656941,          80,        0.6343059,       0.7327137,        true,       true
# Node ID: 179, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.5, -5.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.25, 0.75, -2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.25, 0.75, -2.5, 4.25], Feasibility: true
# Upper Bound: 0.4153753678416949, Solution: [1.25, 0.25, 2.5, 2.25], Feasibility: true
#     92,       81,      -1.5000000,     -1.5000000,     -0.8656941,          81,        0.6343059,       0.7327137,        true,       true
# Node ID: 185, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.75, -5.0, 2.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.25, 0.875, -2.5, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.25, 0.875, -2.5, 4.25], Feasibility: true
# Upper Bound: 0.3708917138094017, Solution: [1.25, 0.125, 2.5, 2.25], Feasibility: true
#     93,       82,      -1.5000000,     -1.5000000,     -0.8656941,          82,        0.6343059,       0.7327137,        true,       true
# Node ID: 187, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.75, -2.5, 2.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 6.5]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.25, 0.875, -1.25, 4.25], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.25, 0.875, -1.25, 4.25], Feasibility: true
# Upper Bound: -0.12531538749824384, Solution: [1.25, 0.125, 1.25, 2.25], Feasibility: true
#     94,       83,      -1.5000000,     -1.5000000,     -0.8656941,          83,        0.6343059,       0.7327137,        true,       true
# Node ID: 188, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.75, -2.5, 2.0], Upper Variable Bounds: [0.0, 1.0, 0.0, 4.25]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.25, 0.875, -1.25, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.25, 0.875, -1.25, 3.125], Feasibility: true
# Upper Bound: -0.26545865967391874, Solution: [1.25, 0.125, 1.25, 1.125], Feasibility: true
#     95,       84,      -1.5000000,     -1.5000000,     -0.8656941,          84,        0.6343059,       0.7327137,        true,       true
# Node ID: 190, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.75, -2.5, 2.0], Upper Variable Bounds: [-1.25, 1.0, 0.0, 4.25]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.875, 0.875, -1.25, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.875, 0.875, -1.25, 3.125], Feasibility: true
# Upper Bound: -0.27114439946165503, Solution: [0.625, 0.125, 1.25, 1.125], Feasibility: true
#     96,       85,      -1.5000000,     -1.5000000,     -0.8656941,          85,        0.6343059,       0.7327137,        true,       true
# Node ID: 193, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.875, -2.5, 2.0], Upper Variable Bounds: [-1.25, 1.0, 0.0, 4.25]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.875, 0.9375, -1.25, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.875, 0.9375, -1.25, 3.125], Feasibility: true
# Upper Bound: -0.2780010081289261, Solution: [0.625, 0.0625, 1.25, 1.125], Feasibility: true
#     97,       86,      -1.5000000,     -1.5000000,     -0.8656941,          86,        0.6343059,       0.7327137,        true,       true
# Node ID: 194, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.875, -2.5, 2.0], Upper Variable Bounds: [-1.25, 1.0, -1.25, 4.25]
# Lower Bound (First Iteration): -1.157661181197635, Solution: [-1.875, 0.9375, -1.875, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.157661181197635, Solution: [-1.875, 0.9375, -1.875, 3.125], Feasibility: true
# Upper Bound: -0.7185705700044364, Solution: [0.625, 0.0625, 0.625, 1.125], Feasibility: true
#     98,       87,      -1.1576612,     -1.5000000,     -0.8656941,          87,        0.6343059,       0.7327137,        true,       true
# Node ID: 192, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.75, -2.5, 2.0], Upper Variable Bounds: [-1.25, 0.875, 0.0, 4.25]
# Lower Bound (First Iteration): -1.2656250000000007, Solution: [-1.875, 0.8125, -1.25, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.2656250000000007, Solution: [-1.875, 0.8125, -1.25, 3.125], Feasibility: true
# Upper Bound: -0.2780010081289261, Solution: [0.625, 0.0625, 1.25, 1.125], Feasibility: true
#     99,       88,      -1.2656250,     -1.5000000,     -0.8656941,          88,        0.6343059,       0.7327137,        true,       true
# Node ID: 195, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.875, -1.25, 2.0], Upper Variable Bounds: [-1.25, 1.0, 0.0, 4.25]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.875, 0.9375, -0.625, 3.125], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.875, 0.9375, -0.625, 3.125], Feasibility: true
# Upper Bound: -0.7185705700044364, Solution: [0.625, 0.0625, 0.625, 1.125], Feasibility: true
# Iteration   NodeID    Current_LBD     Global_LBD     Global_UBD      NodesLeft     Absolute_Gap    Absolute_Ratio     LBD_Feas     UBD_Feas
#    100,       89,      -1.5000000,     -1.5000000,     -0.8656941,          89,        0.6343059,       0.7327137,        true,       true
# Node ID: 201, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.875, -1.25, 3.125], Upper Variable Bounds: [-1.25, 1.0, 0.0, 4.25]
# Lower Bound (First Iteration): -1.3200000000000007, Solution: [-1.875, 0.9375, -0.625, 3.6875], Feasibility: true
# Lower Bound (Last Iteration): -1.3200000000000007, Solution: [-1.875, 0.9375, -0.625, 3.6875], Feasibility: true
# Upper Bound: -1.4394266762312964, Solution: [0.625, 0.0625, 0.625, 0.5625], Feasibility: true
#    101,       40,      -1.3200000,     -1.5000000,     -1.4394267,          40,        0.0605733,       0.0420816,        true,       true
# Node ID: 200, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-2.5, 0.875, -1.25, 2.0], Upper Variable Bounds: [-1.25, 1.0, 0.0, 3.125]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.875, 0.9375, -0.625, 2.5625], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.875, 0.9375, -0.625, 2.5625], Feasibility: true
# Upper Bound: -1.4394266762312964, Solution: [0.625, 0.0625, 0.625, 0.5625], Feasibility: true
#    102,       41,      -1.5000000,     -1.5000000,     -1.4394267,          41,        0.0605733,       0.0420816,        true,       true
# Node ID: 205, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-1.875, 0.875, -1.25, 2.0], Upper Variable Bounds: [-1.25, 1.0, 0.0, 3.125]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.5625, 0.9375, -0.625, 2.5625], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.5625, 0.9375, -0.625, 2.5625], Feasibility: true
# Upper Bound: -1.4405112807561404, Solution: [0.3125, 0.0625, 0.625, 0.5625], Feasibility: true
#    103,       42,      -1.5000000,     -1.5000000,     -1.4405113,          42,        0.0594887,       0.0412969,        true,       true
# Node ID: 207, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-1.875, 0.9375, -1.25, 2.0], Upper Variable Bounds: [-1.25, 1.0, 0.0, 3.125]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.5625, 0.96875, -0.625, 2.5625], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.5625, 0.96875, -0.625, 2.5625], Feasibility: true
# Upper Bound: -1.4414119795293252, Solution: [0.3125, 0.03125, 0.625, 0.5625], Feasibility: true
#    104,       43,      -1.5000000,     -1.5000000,     -1.4414120,          43,        0.0585880,       0.0406463,        true,       true
# Node ID: 209, Lower Bound: -1.5000000000000007, Lower Variable Bounds:
#              [-1.875, 0.9375, -0.625, 2.0], Upper Variable Bounds: [-1.25, 1.0, 0.0, 3.125]
# Lower Bound (First Iteration): -1.5000000000000007, Solution: [-1.5625, 0.96875, -0.3125, 2.5625], Feasibility: true
# Lower Bound (Last Iteration): -1.5000000000000007, Solution: [-1.5625, 0.96875, -0.3125, 2.5625], Feasibility: true
# Upper Bound: -1.691376119161244, Solution: [0.3125, 0.03125, 0.3125, 0.5625], Feasibility: true
#    105,        0,      -1.5000000,     -1.5000000,     -1.6913761,           0,        0.1913761,       0.1275841,        true,       true
# Empty Stack: Exhaustive Search Finished
# First Solution Found at Node 209
# UBD = -1.691376119161244
# Solution is :
#     X[1] = 0.3125
#     X[2] = 0.03125
#     X[3] = 0.3125
#     X[4] = 0.5625

# %% [markdown]
# ### Get information from the JuMP Model object
# The objective value, solution, termination status,  and primal status can then be accessed via the standard JuMP interface.

# %%
fval = JuMP.objective_value(m)
xsol = JuMP.value.(x)
status_term = JuMP.termination_status(m)
status_prim = JuMP.primal_status(m)

println("EAGO terminated with a status of $status_term and a result code of $status_prim")
println("The optimal value is: $fval, the solution found is $xsol.")
# Out:
# EAGO terminated with a status of OPTIMAL and a result code of FEASIBLE_POINT
# The optimal value is: -1.691376119161244, the solution found is [0.3125, 0.03125, 0.3125, 0.5625].

# %% [markdown]
# ### Advice for more advanced constructions
# The *default_lower_problem* and *default_upper_problem* should be used templates for error handling and retreiving information from MOI models. Similarly, the other default routine are good starting points for building custom modifications.
#
# Essentially all of EAGO's subroutines are stored to a field in the **EAGO.Optimizer** structure can be reset as user-defined functions.
#
# ### References
# 1. IntervalArithmetic.jl [Computer software] (2019). Retrieved from https://github.com/JuliaIntervals/IntervalArithmetic.jl
# 2. Iain Dunning and Joey Huchette and Miles Lubin. JuMP: A Modeling Language for Mathematical Optimization, *SIAM Review*, **SIAM** 59 (2017), pp. 295-320.
